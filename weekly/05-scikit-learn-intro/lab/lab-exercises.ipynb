# %% [markdown]
# # Week 5 Lab — scikit-learn on the Titanic
#
# Work through the exercises below in order. Setup is done for you in the next cell — run it first, then write your answer in the empty cell under each exercise.

# %%
# Setup — run me first
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('./data/titanic.csv')
data.info()

# %% [markdown]
# #### **Exercise 1**
#
# A couple of weeks ago, we started looking at the Titanic data. Load that data again (done for you above). For features that you think are of minimal importance and / or have too many NAs to make imputation feasible, drop those features. For those that seem important, use a `SimpleImputer` to impute the data.

# %%
# Answer here

# %% [markdown]
# #### **Exercise 2**
#
# Sklearn does not handle strings. Use an encoder to transform any string columns into numbers. If there are any categorical columns where label encoding won't work, use a one-hot encoder.

# %%
# Answer here

# %% [markdown]
# #### **Exercise 3**
#
# Using 5-fold cross-validation, examine the performance of a `LogisticRegression` classifier.

# %%
# Answer here

# %% [markdown]
# ---
#
# ### Extension exercises (optional)
#
# > ⚠️ Exercises 4–6 use a **decision tree** and **`GridSearchCV`**, which we haven't covered yet — and that's the point. You don't need to know *how* a decision tree works to use one. A good API (scikit-learn's) lets you swap in almost any algorithm by changing a single line. Try these to feel that power for yourself; don't get into the weeds on the internals — we'll cover trees later in the course.

# %% [markdown]
# #### **Exercise 4** (extension)
#
# Replace the logistic regression classifier with a decision tree classifier. Which works better? Why do you think that is?

# %%
# Answer here

# %% [markdown]
# #### **Exercise 5** (extension)
#
# See if you can get the decision tree classifier to perform better. You might try:
#
# - Making sure you use the `fare` column.
# - Using a smarter imputation mechanism for your columns (try figuring out the `KNNImputer`).
# - Modifying the `DecisionTreeClassifier` parameters.

# %%
# Answer here

# %% [markdown]
# #### **Exercise 6** (extension)
#
# Try using a `GridSearchCV` to optimize the decision tree. What is the best performance you can achieve?

# %%
# Answer here
