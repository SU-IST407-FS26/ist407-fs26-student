# %% [markdown]
# # Week 2 — Weekly Exercises: Visualizing Data
#
# A light set to prepare for class. The TSA data is in `./data/`. All three are required.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Exercise 1
#
# Using the TSA traveler throughput data in `./data/tsa_melted_holiday_travel.csv`, create **box plots** of traveler throughput for each year.
#
# *Hint:* pass `kind='box'` to the `plot()` method (pivot the data so each year is a column first).

# %% [markdown]
# ### Exercise 2
#
# Plot TSA traveler throughput **over time** as a line plot: parse the `date` column as dates and plot `travelers` against `date`.
#
# *Hint:* `pd.read_csv(..., parse_dates=['date'])`, then `df.plot(x='date', y='travelers')`.

# %% [markdown]
# ### Exercise 3
#
# Plot a **histogram** of the daily `travelers` counts to see their distribution.
#
# *Hint:* `df['travelers'].plot(kind='hist', bins=30)`.
